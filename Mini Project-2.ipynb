# %%
import pandas as pd 
df=pd.read_csv("weather_data.csv")
df
# Out:
#          Date          City  Temperature_C  Humidity_% Condition
# 0  01-01-2025      Hyderbad             28          60     Sunny
# 1  02-01-2025    Vijayawada             29          62     Sunny
# 2  03-01-2025  Viskhapatnam             30          58    Cloudy
# 3  04-01-2025      Kakinada             31          55    Cloudy
# 4  05-01-2025      Banglore             32          57     Rainy
# 5  06-01-2025        Mumbai             33          59     Rainy
# 6  07-01-2025       Chennai             34          61     Sunny
# 7  08-01-2025    Rajamundry             32          63    Cloudy
# 8  09-01-2025         Eluru             31          64     Rainy
# 9  10-01-2025    Anakapalli             29          62     Sunny

# %%
df["Humidity_%"].max()
# Out:
# 64

# %%
df["Humidity_%"].min()
# Out:
# 55

# %%
df["Humidity_%"].mean()
# Out:
# 60.1

# %%
df["Humidity_%"].describe()
# Out:
# count    10.00000
# mean     60.10000
# std       2.84605
# min      55.00000
# 25%      58.25000
# 50%      60.50000
# 75%      62.00000
# max      64.00000
# Name: Humidity_%, dtype: float64

# %%
import pandas as pd
df[df.Temperature_C==df.Temperature_C.max()]
# Out:
#          Date     City  Temperature_C  Humidity_% Condition
# 6  07-01-2025  Chennai             34          61     Sunny

# %%
df.count()
# Out:
# Date             10
# City             10
# Temperature_C    10
# Humidity_%       10
# Condition        10
# dtype: int64

# %%
df['City'].nunique()
# Out:
# 10

# %%
df['City'].unique()
# Out:
# array(['Hyderbad', 'Vijayawada', 'Viskhapatnam', 'Kakinada', 'Banglore',
#        'Mumbai', 'Chennai', 'Rajamundry', 'Eluru', 'Anakapalli'],
#       dtype=object)

# %%
df['City'].value_counts()
# Out:
# City
# Hyderbad        1
# Vijayawada      1
# Viskhapatnam    1
# Kakinada        1
# Banglore        1
# Mumbai          1
# Chennai         1
# Rajamundry      1
# Eluru           1
# Anakapalli      1
# Name: count, dtype: int64
